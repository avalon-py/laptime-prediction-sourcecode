# %%
import pandas as pd

df = pd.read_parquet("data/raw/year=2023/round=3/R_race_control.parquet")
df.to_csv('testing.csv')

# %%
df.columns
# Out:
# Index(['Time', 'Category', 'Message', 'Status', 'Flag', 'Scope', 'Sector',
#        'RacingNumber', 'Lap', 'Year', 'RoundNumber', 'EventName'],
#       dtype='object')

# %%
df = pd.read_parquet("data/features+status_5Hz_quali/year=2024_round=8.parquet")
df['corner_density'].value_counts()
# Out:
# corner_density
# 0.005828    476670
# Name: count, dtype: int64
